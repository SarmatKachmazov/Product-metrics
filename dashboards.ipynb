# %%
from IPython.display import Image
Image(filename='/Users/fixed/Desktop/dashboard_1.png')

# %%
Image(filename='/Users/fixed/Desktop/dashboard_2.png')

# %%
Image(filename='/Users/fixed/Desktop/dashboard_3.png')

# %%
Image(filename='/Users/fixed/Desktop/dashboard_4.png')

# %%
Image(filename='/Users/fixed/Desktop/dashboard_5.png')
